# %%
import datagen
import matplotlib.pyplot as plt     
import numpy as np

# %%
signal = datagen.genIridiumSimplex(0, plotDebug=True,printDebug=True)
# Out:
# 41615
# Total samples:  42000
# Total Timesteps:  42000
# Pre signal noise samples:  226
# Preamble samples:  5242
# BPSK samples:  983
# QPSK samples:  35390
# (35390,)
# Post signal noise samples:  159

# %%
signal.shape
# Out:
# (42000,)

# %%
SNRs = np.arange(-20, 20)
for SNR in SNRs:
    constantSine = datagen.genQPSKNoise(SNR)
    constantNoise = datagen.genQPSKNoiseUnscaled(SNR)

    plt.plot(constantSine)
    plt.plot(constantNoise)
    plt.show()
# Out:
# SNR True -19.999999999999996
# SNR True -20.0
# SNR True -19.0
# SNR True -19.0
# SNR True -18.0
# SNR True -18.000000000000004
# SNR True -16.999999999999996
# SNR True -17.0
# SNR True -16.0
# SNR True -16.0
# SNR True -15.0
# SNR True -15.0
# SNR True -14.0
# SNR True -14.0
# SNR True -13.0
# SNR True -13.0
# SNR True -12.0
# SNR True -12.0
# SNR True -11.0
# SNR True -11.0
# SNR True -10.0
# SNR True -10.000000000000002
# SNR True -9.0
# SNR True -9.0
# SNR True -8.0
# SNR True -7.999999999999999
# SNR True -7.0
# SNR True -7.0
# SNR True -6.000000000000002
# SNR True -6.000000000000001
# SNR True -5.0
# SNR True -4.999999999999998
# SNR True -3.9999999999999996
# SNR True -4.000000000000002
# SNR True -3.0000000000000004
# SNR True -3.0000000000000004
# SNR True -2.0000000000000013
# SNR True -1.9999999999999971
# SNR True -1.0
# SNR True -1.0000000000000013
# SNR True -1.446491199829931e-15
# SNR True 0.0
# SNR True 0.999999999999998
# SNR True 1.0000000000000002
# ...
